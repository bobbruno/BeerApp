# %%
import socks
import socket
import mechanize
import bs4
import time
import random
from itertools import cycle

def create_connection(address, timeout=None, source_address=None):
    sock = socks.socksocket()
    sock.connect(address)
    return sock

socks.setdefaultproxy(socks.PROXY_TYPE_SOCKS5, "127.0.0.1", 9050)
# patch the socket module
socket.socket = socks.socksocket
socket.create_connection = create_connection
        
br = mechanize.Browser()

# %%
br.addheaders = [('User-agent', 'Mozilla/5.0 (Windows NT 6.1; rv:27.3) Gecko/20130101 Firefox/27.3')]
br.open('http://www.ratebeer.com/breweries/kentucky/0/56/')
# Out:
# ---------------------------------------------------------------------------
# httperror_seek_wrapper                    Traceback (most recent call last)
# <ipython-input-28-57dd61030ade> in <module>()
#       1 br.addheaders = [('User-agent', 'Mozilla/5.0 (Windows NT 6.1; rv:27.3) Gecko/20130101 Firefox/27.3')]
# ----> 2 br.open('http://www.ratebeer.com/breweries/kentucky/0/56/')
#
# /usr/lib/python2.7/dist-packages/mechanize/_mechanize.pyc in open(self, url, data, timeout)
#     201     def open(self, url, data=None,
#     202              timeout=_sockettimeout._GLOBAL_DEFAULT_TIMEOUT):
# --> 203         return self._mech_open(url, data, timeout=timeout)
#     204
#     205     def _mech_open(self, url, data=None, update_history=True, visit=None,
#
# /usr/lib/python2.7/dist-packages/mechanize/_mechanize.pyc in _mech_open(self, url, data, update_history, visit, timeout)
#     253
#     254         if not success:
# --> 255             raise response
#     256         return response
#     257
#
# httperror_seek_wrapper: HTTP Error 404: Not Found

# %%
print br.response().read()
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <title>Kentucky                         Breweries</title>
# <meta content="Kentucky                         Breweries, breweries, Brewery and brewpub directory." name="Description">
# <meta content="Brewery, brew pubs, brewpub, Breweries, brew pub, brewpub directory, brewpub resources" name="Keywords">
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.7/jquery.min.js"></script>
# <script type="text/javascript" src="/javascript/jquery.tablesorter.min.js"></script>
#
# <link rel="stylesheet" href="/tags/tags.css" type="text/css">
# <script type='text/javascript'>
# $(document).ready(function(){
# 	$("#showInfo").hover(function() {
# 		$("#hideInfo").show();
# 			}, function() {
# 		$("#hideInfo").hide();
# 	});
# 	$("#brewerTable").tablesorter( {sortList: [[0,0], [0,0], [2,0], [3,0]]} );;
# });
# </script>
# <style type="text/css">
# #rightcol a:visited, #rightcol a:link {
# 	font-weight: bold; color: #FFFBF0;
# }
#
# #hideInfo {
# 	position: absolute;
# 	z-index: 99;
# 	background: #fff;
# 	padding: 5px;
# 	font-size: 10px;
# 	right: 0px;
# 	top: 0px;
# 	line-height: 1.3em;
# }
# TH {
# 	border-bottom: 2px solid #f0f0f0;
# }
# </style>
# <link rel="stylesheet" href="/css_core.css?v=201407" type="text/css">
# <meta http-equiv="content-language" content="EN">
# <link rel="shortcut icon" href="/favicon.ico">
#
# <script type='text/javascript' src='http://partner.googleadservices.com/gampad/google_service.js'>
# </script>
# <script type='text/javascript'>
# GS_googleAddAdSenseService("ca-pub-4822594167621467");
# GS_googleEnableAllServices();
# </script>
# <script type='text/javascript'>
# GA_googleAddSlot("ca-pub-4822594167621467", "header-leaderboard");
# GA_googleAddSlot("ca-pub-4822594167621467", "beerpage468");
# </script>
# <script type='text/javascript'>
# GA_googleFetchAds();
# </script>
# </head>
#
# <body alink="#CC3300" link="#003388" vlink="#330044" text="#333333" marginheight="14" marginwidth="0" topmargin="0" leftmargin="0" >
# <div id="rbbody">
# <table align="center" width="1000" cellpadding="0" cellspacing="0" border="0" style="height: 80px; z-index:5;">
#         <tr>
#         <td rowspan="2">
#
# 		<a href="/"><img src="/images/logos/rblogo042013.png" alt="RateBeer" border="0" width="180" height="52" style="padding-left: 20px; padding-top: 0px;"></a>
#
#
#         </td>
#         <td valign="top" align="right" style="padding: 14px 12px 0px 0px;">
#
# 			<div class="no-print">
#                 <FORM action="/findbeer.asp" method=POST name=search>
#                 <span style="color:#fff"><a href="/NewUser.asp"><span style="color: #fff;">Sign Up</b></a> or <a href="/login.asp"><span style="color: #fff;">Login</span></a></span>
#                 <span style="color:#fff">:</span> <A HREF="/search.php"><span style="color:#fff">Advanced Search</span></A> &nbsp; <input type="text" name="BeerName" value="" size="3" STYLE="padding: 0px 6px;width: 230px; height: 25px; font-size: 12px; background-color:#fff; border: 0px; border-radius: 28px;"><input type="submit" style="margin-left: 3px; height: 25px; width: 26px; border: 0px; position: relative; top: -1px;background-color:#4d90fe; border-radius: 20px;font-size:10px;color:#fff;cursor: pointer;padding-top: 1px;" value="GO" />
# 				</FORM>
# 			</div>
#         </td></tr>
#
#         <tr><td align="right" valign="bottom"><table border=0 cellpadding=0 cellspacing=0><tr><td align="right">
#                 <ul id="nav" class="no-print">
#                 <li><a  href="/places/mylocal.asp">Local</a></li>
#                     <li ><a  href="/beer-ratings/">Ratings</a>
#
#
#                     <li><a  href="/users">People</a></li>
#
#
#
#                     <li><a  href="/shop">Shop</a></li>
#
#
#                     <li><a  href="/events">Events</a></li>
#
#
#
#                     <li><a  href="/places/browse/">Places</a></li>
#
#                     <li><a  href="/forums/">Forums</a></li>
#
#
#                 </ul></td></tr></table></td></tr></table></td></tr></table>
#
# <div id="container">
#
#
#
# <!-- Content begins -->
#
# <TABLE width="100%" cellpadding="20" cellspacing="0" border="0">
# <TR>
# <td valign="top" width="160" style="background: #f9f9f9;">
# <div id="taghome">
#
# <!-- <a href="/"><img src="/images/icons/home.png" border="0"> Home</a> &gt; <a href="/breweries/">Breweries</a></div> -->
#
# <div>
#
# <form name="jump1">
# 		<select class="curvy" style="background-color: #E9F3Ff; color: #333; font-size: 12px; padding: 4px; border: 1px solid #B9DAF0;width: 190px;" name="menu" id="menu" onchange="location=document.getElementById('menu').value;" value="GO">
# 		<option value="/breweries/kentucky-------------breweries/17/213/">Kentucky                         Breweries</option>
# 		<option value="/breweries/">All Breweries</option>
# 		<option value="/cider/">All Cideries</option>
# 		<option value="/mead/">All Meaderies</option>
# 		<option value="/sake/">All Sake Producers</option>
# </select>
# </form>
# </div>
#
# <div id="tagside">
#
#
# <!--
# <div class="menu"><a href="/tag/showall/">Tags</a></div>
# <div class="menu"><a href="/tag/showall/">Tags</a></div>
# -->
#
# <div id="">top styles
# <p style="font-size:12px;"><a href="/beerstyles/india-pale-ale-ipa/17/">India Pale Ale &#40;IPA&#41;</a> &nbsp;86<br><a href="/beerstyles/brown-ale/15/">Brown Ale</a> &nbsp;46<br><a href="/beerstyles/american-pale-ale/18/">American Pale Ale</a> &nbsp;46<br><a href="/beerstyles/imperial-stout/24/">Imperial Stout</a> &nbsp;44<br><a href="/beerstyles/stout/6/">Stout</a> &nbsp;35<br></p>
#
# <div style="white-space: nowrap;" id="">tags</div>
# <p style="font-size:12px;"><a href="/tag/bourbon-barrel/">#bourbon barrel</a> <a href="/tag/rye/">#rye</a> <a href="/tag/coffee/">#coffee</a> <a href="/tag/barrel-aged/">#barrel-aged</a> <a href="/tag/centennial/">#centennial</a> <a href="/tag/maris-otter/">#maris otter</a> <a href="/tag/saaz/">#saaz</a> <a href="/tag/simcoe/">#simcoe</a> <a href="/tag/citra/">#citra</a> <a href="/tag/collaboration/">#collaboration</a> </p>
#
# <p style="font-size:12px;">
# <table ><tr><td id="tagside nowrap">top raters</td><td nowrap style="color: #999; float:right; font-size: 12px;">24 total</td></tr>
# <tr><td colspan=2><span class="userpic"><img src="http://res.cloudinary.com/ratebeer/image/upload/w_50,h_50,c_limit,q_80,d_user_def.gif/user_Tmoney99.jpg" width=30 height=30></span><span class="userTagList"><a href="/user/11116/">Tmoney99</a> &nbsp;18</span></td></tr><tr><td colspan=2><span class="userpic"><img src="http://res.cloudinary.com/ratebeer/image/upload/w_50,h_50,c_limit,q_80,d_user_def.gif/user_Chudwick.jpg" width=30 height=30></span><span class="userTagList"><a href="/user/105404/">Chudwick</a> &nbsp;18</span></td></tr><tr><td colspan=2><span class="userpic"><img src="http://res.cloudinary.com/ratebeer/image/upload/w_50,h_50,c_limit,q_80,d_user_def.gif/user_shrubber85.jpg" width=30 height=30></span><span class="userTagList"><a href="/user/10924/">shrubber85</a> &nbsp;17</span></td></tr><tr><td colspan=2><span class="userpic"><img src="http://res.cloudinary.com/ratebeer/image/upload/w_50,h_50,c_limit,q_80,d_user_def.gif/user_rondphoto.jpg" width=30 height=30></span><span class="userTagList"><a href="/user/65843/">rondphoto</a> &nbsp;16</span></td></tr><tr><td colspan=2><span class="userpic"><img src="http://res.cloudinary.com/ratebeer/image/upload/w_50,h_50,c_limit,q_80,d_user_def.gif/user_ContemplateBeer.jpg" width=30 height=30></span><span class="userTagList"><a href="/user/79318/">ContemplateBeer</a> &nbsp;16</span></td></tr>
# </table></p>
#
#
#
# </div>
# </td>
#
# <TD valign="top" width="800">
#
#
#
#
# <div id="brewerCover">
# <h1>Kentucky                         Breweries</h1>
#  (<a id=showInfo href='#' style='color:#999;'>18 active</a>)<div id=hideInfo style="display: none;">Commercial Brewery - 0<br>Microbrewery - 10<br>Brewpub - 6<br>Brewpub/Brewery - 4<br>Contract Brewer - 0<br>Client Brewer - 4<br></div>
# </div>
#
#
# <div>
#
# <br><TABLE width="100%" id="brewerTable" class="tbl" class="tablesorter"><thead><tr class="tbl head"><th align=left><a href="#">Brewer</a></th><th align=left><a href="#">Type</a></th><th><a href="#"># Beer</a></th><th><a href="#">My Ratings</a></th><th><a href="#">Est.</a></th></tr></thead><tbody><tr><td style="padding-left: 4px;"><A HREF="/brewers/against-the-grain-brewery/13546/"> Against the Grain Brewery</A> - Louisville</td><td>Brewpub/Brewery</td><td style="text-align:center;">212</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2011</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/apocalypse-brew-works/14450/"> Apocalypse Brew Works</A> - Louisville</td><td>Microbrewery</td><td style="text-align:center;">57</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2012</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/beer-engine-ky/13567/"> Beer Engine &#40;KY&#41;</A> - Danville</td><td>Brewpub</td><td style="text-align:center;">11</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2011</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/blue-stallion-brewing-company/17186/"> Blue Stallion Brewing Company</A> - Lexington</td><td>Brewpub/Brewery</td><td style="text-align:center;">24</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2013</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/bluegrass-brewing-company/513/"> Bluegrass Brewing Company</A> - Louisville</td><td>Microbrewery</td><td style="text-align:center;">247</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">1993</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/country-boy-brewing/14109/"> Country Boy Brewing</A> - Lexington</td><td>Brewpub/Brewery</td><td style="text-align:center;">92</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2012</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/cumberland-brews/798/"> Cumberland Brews</A> - Louisville</td><td>Brewpub</td><td style="text-align:center;">102</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2000</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/ei8ht-ball-brewing/18113/"> Ei8ht Ball Brewing</A> - Bellevue</td><td>Brewpub</td><td style="text-align:center;">16</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2013</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/falls-city-beer-company/11585/"> Falls City Beer Company</A> - Louisville</td><td>Client Brewer</td><td style="text-align:center;">10</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2010</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/geo-wiedemann-brewing-company/15785/"> Geo. Wiedemann Brewing Company</A> - Newport</td><td>Client Brewer</td><td style="text-align:center;">8</TD><td style="text-align:center;"><img src="/images/checkbox.gif"> <font style="color: #ccc;">-</font></td><td style="color:#ccc;font-size: 10px;align:right;">2012</td></TR><tr><td style="padding-left: 4px;"><A HREF="/brewers/great-flood-brewing-company/19366/"> Great Flood Brewing Company</A> - Loui ...
# </span>
# </div>
# </TD>
# </TR>
# </TABLE>
#
# <!-- Content ends -->
#
# <!-- Footer begins -->
# </div>
# <center>
# <style type="text/css">#foota a {color: #fff;}
# </style>
# <div style="width: 1000px; vertical-align: middle; color: #fff;z-index: 5;">
# <div style="float: left; width: 200px;  padding: 14px 0px 20px 0px; text-align: left; color: #999;z-index: 5;">
# <small>Copyright &copy; 2000-2014,<br />
# RateBeer LLC. All rights<br />
# reserved.</small>
# </div>
#
# <div style="float: right; width: 200px; padding: 14px 0px 0px 0px; text-align: right;z-index: 5;"><img src="/images/logos/rb_white_footer.png" /></div>
#
# <table cellpadding=14 cellspacing=0 border=0 id="foota">
# <tr><td valign=top style="border-right: 1px solid #457; font-size: 12px; text-align: left;">
# <big><strong style="color: #a7bbcc;">about us</strong></big><br />
# <a href="/About.asp">About RateBeer</a><br />
# <a href="/FAQ.asp">FAQ</a><br />
# <a href="/Feedback.asp">Contact/Feedback</a><br />
# <a href="/newbeers.asp">New Beers</a><br />
#
#
# </td><td valign=top style="border-right: 1px solid #457; font-size: 12px; text-align: left;">
# <big><strong style="color: #a7bbcc;">add</strong></big><br />
# <a href="/search.php">Advanced Search</a><br />
# <a href="/AddBeer.asp">Add A Beer</a> <br />
# <a href="/AddBrewer.asp">Add A Brewer</a><br />
# <a href="/Places/AddAPlace.asp">Add A Place</a> <br />
# <a href="/events.asp">Events</a><br />
#
# </td><td valign=top style="border-right: 1px solid #457; font-size: 12px; text-align: left;">
# <big><strong style="color: #a7bbcc;">membership</strong></big><br />
# <a href="/login.asp">Log In</a><br />
# <a href="/EditUser.asp">Edit Personal Info</a><br />
# <a href="/AboutPremium_Join.asp">Buy Premium Membership</a><br />
# <a href="/Messages.asp">Your Messages</a><br />
#
# </td><td valign=top style="font-size: 12px; text-align: left;">
# <big><strong style="color: #a7bbcc;">the best</strong></big><br />
# <a href="/ratebeerbest/">RateBeer Best</a><br />
# <a href="/Ratings/beerClub.asp">100 Beer Club</a><br />
# <a href="/beer/top-50/">The Top 50</a><br />
#
# </td>
# </tr>
# </table>
#
# <br />
#
# <div style="clear:both;"></div>
# </div>
# </center>
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-1881232-1', 'ratebeer.com');
#   ga('require', 'displayfeatures');
#   ga('send', 'pageview');
# </script>
#
#
# <!-- Footer ends -->
